# %% [markdown]
# ### Imports

# %%
import pandas as pd
import requests as req
#import math
#import numpy as np
import os.path

# %% [markdown]
# ### Input Data

# %%
df =pd.read_csv('../data/stars_classification_with_images.csv')

df
# Out:
#              obj_ID       alpha      delta         u         g         r  \
# 0      1.237680e+18  340.995121  20.589476  23.48827  23.33776  21.32195
# 1      1.237679e+18   23.234926  11.418188  21.46973  21.17624  20.92829
# 2      1.237679e+18    5.433176  12.065186  22.24979  22.02172  20.34126
# 3      1.237661e+18  200.290475  47.199402  24.40286  22.35669  20.61032
# 4      1.237671e+18   39.149691  28.102842  21.74669  20.03493  19.17553
# ...             ...         ...        ...       ...       ...       ...
# 99995  1.237679e+18   39.620709  -2.594074  22.16759  22.97586  21.90404
# 99996  1.237679e+18   29.493819  19.798874  22.69118  22.38628  20.45003
# 99997  1.237668e+18  224.587407  15.700707  21.16916  19.26997  18.20428
# 99998  1.237661e+18  212.268621  46.660365  25.35039  21.63757  19.91386
# 99999  1.237661e+18  196.896053  49.464643  22.62171  21.79745  20.60115
#
#               i         z  run_ID  rerun_ID  cam_col  field_ID   spec_obj_ID  \
# 0      20.25615  19.54544    8102       301        3       110  5.658977e+18
# 1      20.60826  20.42573    7773       301        2       462  1.246262e+19
# 2      19.48794  18.84999    7773       301        2       346  6.961443e+18
# 3      19.46490  18.95852    3716       301        5       108  7.459285e+18
# 4      18.81823  18.65422    5934       301        4       122  2.751763e+18
# ...         ...       ...     ...       ...      ...       ...           ...
# 99995  21.30548  20.73569    7778       301        2       581  1.055431e+19
# 99996  19.75759  19.41526    7917       301        1       289  8.586351e+18
# 99997  17.69034  17.35221    5314       301        4       308  3.112008e+18
# 99998  19.07254  18.62482    3650       301        4       131  7.601080e+18
# 99999  20.00959  19.28075    3650       301        4        60  8.343152e+18
#
#         class  redshift  plate    MJD  fiber_ID  \
# 0         QSO  1.424659   5026  55855       741
# 1         QSO  0.586455  11069  58456       113
# 2      GALAXY  0.477009   6183  56210        15
# 3      GALAXY  0.660012   6625  56386       719
# 4        STAR -0.000008   2444  54082       232
# ...       ...       ...    ...    ...       ...
# 99995  GALAXY  0.000000   9374  57749       438
# 99996  GALAXY  0.404895   7626  56934       866
# 99997  GALAXY  0.143366   2764  54535        74
# 99998  GALAXY  0.455040   6751  56368       470
# 99999  GALAXY  0.542944   7410  57104       851
#
#                                                image_url
# 0      https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# 1      https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# 2      https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# 3      https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# 4      https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# ...                                                  ...
# 99995  https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# 99996  https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# 99997  https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# 99998  https://dr12.sdss.org//sas/dr12/boss/photoObj/...
# 99999  https://dr12.sdss.org//sas/dr12/boss/photoObj/...
#
# [100000 rows x 19 columns]

# %% [markdown]
# ### Get image subset locally

# %%
def get_star_image(url):
    image_name = url.split('/')[-1]
    if not os.path.isfile(f'../data/images/{image_name}'):
        resp = req.get(url)
        f = open(f'../data/images/{image_name}','wb')
        f.write(resp.content)
        f.close()

# %%
'''for index, row in df.iterrows():
    if index < 11:
        get_star_image(row['image_url'])'''
# Out:
# "for index, row in df.iterrows():\n    if index < 11:\n        get_star_image(row['image_url'])"

# %%
for index in range(133,1000):
    row = df.iloc[index]
    url = row['image_url']
    if not pd.isna(url):
        get_star_image(url)
        print(f'retrieving image with index {index}')
# Out:
# retrieving image with index 133
# retrieving image with index 135
# retrieving image with index 136
# retrieving image with index 137
# retrieving image with index 138
# retrieving image with index 139
# retrieving image with index 140
# retrieving image with index 141
# retrieving image with index 142
# retrieving image with index 143
# retrieving image with index 144
# retrieving image with index 145
# retrieving image with index 146
# retrieving image with index 147
# retrieving image with index 148
# retrieving image with index 149
# retrieving image with index 150
# retrieving image with index 151
# retrieving image with index 152
# retrieving image with index 153
# retrieving image with index 154
# retrieving image with index 155
# retrieving image with index 156
# retrieving image with index 157
# retrieving image with index 158
# retrieving image with index 159
# retrieving image with index 160
# retrieving image with index 161
# retrieving image with index 162
# retrieving image with index 163
# retrieving image with index 164
# retrieving image with index 165
# retrieving image with index 166
# retrieving image with index 167
# retrieving image with index 168
# retrieving image with index 169
# retrieving image with index 170
# retrieving image with index 171
# retrieving image with index 172
# retrieving image with index 173
# retrieving image with index 174
# retrieving image with index 175
# retrieving image with index 176
# retrieving image with index 177
# retrieving image with index 178
# retrieving image with index 179
# retrieving image with index 180
# retrieving image with index 181
# retrieving image with index 182
# retrieving image with index 183
# retrieving image with index 184
# retrieving image with index 185
# retrieving image with index 186
# retrieving image with index 187
# retrieving image with index 188
# retrieving image with index 189
# retrieving image with index 190
# retrieving image with index 191
# retrieving image with index 192
# retrieving image with index 193
# retrieving image with index 194
# retrieving image with index 195
# retrieving image with index 196
# retrieving image with index 197
# retrieving image with index 198
# retrieving image with index 199
# retrieving image with index 200
# retrieving image with index 201
# retrieving image with index 202
# retrieving image with index 203
# retrieving image with index 204
# retrieving image with index 205
# retrieving image with index 206
# retrieving image with index 207
# retrieving image with index 208
# retrieving image with index 209
# retrieving image with index 210
# retrieving image with index 211
# retrieving image with index 212
# retrieving image with index 213
# retrieving image with index 214
# retrieving image with index 215
# retrieving image with index 216
# retrieving image with index 217
# retrieving image with index 218
# retrieving image with index 219
# retrieving image with index 220
# retrieving image with index 221
# retrieving image with index 222
# retrieving image with index 223
# retrieving image with index 224
# retrieving image with index 225
# retrieving image with index 226
# retrieving image with index 227
# retrieving image with index 228
# retrieving image with index 229
# retrieving image with index 230
# retrieving image with index 231
# retrieving image with index 232
# retrieving image with index 233
# retrieving image with index 234
# retrieving image with index 235
# retrieving image with index 236
# retrieving image with index 237
# retrieving image with index 238
# retrieving image with index 239
# retrieving image with index 240
# retrieving image with index 241
# retrieving image with index 242
# retrieving image with index 243
# retrieving image with index 244
# retrieving image with index 245
# retrieving image with index 246
# retrieving image with index 247
# retrieving image with index 248
# retrieving image with index 249
# retrieving image with index 250
# retrieving image with index 251
# retrieving image with index 252
# retrieving image with index 253
# retrieving image with index 254
# retrieving image with index 255
# retrieving image with index 256
# retrieving image with index 257
# retrieving image with index 258
# retrieving image with index 259
# retrieving image with index 260
# retrieving image with index 261
# retrieving image with index 262
# retrieving image with index 263
# retrieving image with index 264
# retrieving image with index 265
# retrieving image with index 266
# retrieving image with index 267
# retrieving image with index 268
# retrieving image with index 269
# retrieving image with index 270
# retrieving image with index 271
# retrieving image with index 272
# retrieving image with index 273
# retrieving image with index 274
# retrieving image with index 275
# retrieving image with index 276
# retrieving image with index 277
# retrieving image with index 278
# retrieving image with index 279
# retrieving image with index 280
# retrieving image with index 281
# retrieving image with index 282
# retrieving image with index 283
# retrieving image with index 284
# retrieving image with index 285
# retrieving image with index 286
# retrieving image with index 287
# retrieving image with index 288
# retrieving image with index 289
# retrieving image with index 290
# retrieving image with index 291
# retrieving image with index 292
# retrieving image with index 293
# retrieving image with index 294
# retrieving image with index 295
# retrieving image with index 296
# retrieving image with index 297
# retrieving image with index 298
# retrieving image with index 299
# retrieving image with index 300
# retrieving image with index 301
# retrieving image with index 302
# retrieving image with index 303
# retrieving image with index 304
# retrieving image with index 305
# retrieving image with index 306
# retrieving image with index 307
# retrieving image with index 308
# retrieving image with index 309
# retrieving image with index 310
# retrieving image with index 311
# retrieving image with index 312
# retrieving image with index 313
# retrieving image with index 314
# retrieving image with index 315
# retrieving image with index 316
# retrieving image with index 317
# retrieving image with index 318
# retrieving image with index 319
# retrieving image with index 320
# retrieving image with index 321
# retrieving image with index 322
# retrieving image with index 323
# retrieving image with index 325
# retrieving image with index 326
# retrieving image with index 327
# retrieving image with index 328
# retrieving image with index 329
# retrieving image with index 330
# retrieving image with index 331
# retrieving image with index 332
# retrieving image with index 333
# retrieving image with index 334
# retrieving image with index 335
# retrieving image with index 336
# retrieving image with index 337
# retrieving image with index 338
# retrieving image with index 339
# retrieving image with index 340
# retrieving image with index 341
# retrieving image with index 342
# retrieving image with index 343
# retrieving image with index 344
# retrieving image with index 345
# retrieving image with index 346
# retrieving image with index 347
# retrieving image with index 348
# retrieving image with index 349
# retrieving image with index 350
# retrieving image with index 351
# retrieving image with index 352
# retrieving image with index 353
# retrieving image with index 354
# retrieving image with index 355
# retrieving image with index 356
# retrieving image with index 357
# retrieving image with index 358
# retrieving image with index 359
# retrieving image with index 360
# retrieving image with index 361
# retrieving image with index 362
# retrieving image with index 363
# retrieving image with index 364
# retrieving image with index 365
# retrieving image with index 366
# retrieving image with index 367
# retrieving image with index 368
# retrieving image with index 369
# retrieving image with index 370
# retrieving image with index 371
# retrieving image with index 372
# retrieving image with index 373
# retrieving image with index 374
# retrieving image with index 375
# retrieving image with index 376
# retrieving image with index 377
# retrieving image with index 378
# retrieving image with index 379
# retrieving image with index 380
# retrieving image with index 381
# retrieving image with index 382
# retrieving image with index 383
# retrieving image with index 384
# retrieving image with index 385
# retrieving image with index 386
# retrieving image with index 387
# retrieving image with index 388
# retrieving image with index 389
# retrieving image with index 390
# retrieving image with index 391
# retrieving image with index 392
# retrieving image with index 393
# retrieving image with index 394
# retrieving image with index 395
# retrieving image with index 396
# retrieving image with index 397
# retrieving image with index 398
# retrieving image with index 399
# retrieving image with index 400
# retrieving image with index 401
# retrieving image with index 402
# retrieving image with index 403
# retrieving image with index 404
# retrieving image with index 405
# retrieving image with index 406
# retrieving image with index 407
# retrieving image with index 408
# retrieving image with index 409
# retrieving image with index 410
# retrieving image with index 411
# retrieving image with index 412
# retrieving image with index 413
# retrieving image with index 414
# retrieving image with index 415
# retrieving image with index 416
# retrieving image with index 417
# retrieving image with index 418
# retrieving image with index 419
# retrieving image with index 420
# retrieving image with index 421
# retrieving image with index 422
# retrieving image with index 423
# retrieving image with index 424
# retrieving image with index 425
# retrieving image with index 426
# retrieving image with index 427
# retrieving image with index 428
# retrieving image with index 429
# retrieving image with index 430
# retrieving image with index 431
# retrieving image with index 432
# retrieving image with index 433
# retrieving image with index 434
# retrieving image with index 435
# retrieving image with index 436
# retrieving image with index 437
# retrieving image with index 438
# retrieving image with index 439
# retrieving image with index 440
# retrieving image with index 441
# retrieving image with index 442
# retrieving image with index 443
# retrieving image with index 444
# retrieving image with index 445
# retrieving image with index 446
# retrieving image with index 447
# retrieving image with index 448
# retrieving image with index 449
# retrieving image with index 450
# retrieving image with index 451
# retrieving image with index 452
# retrieving image with index 453
# retrieving image with index 454
# retrieving image with index 455
# retrieving image with index 456
# retrieving image with index 457
# retrieving image with index 458
# retrieving image with index 459
# retrieving image with index 460
# retrieving image with index 461
# retrieving image with index 462
# retrieving image with index 463
# retrieving image with index 464
# retrieving image with index 465
# retrieving image with index 466
# retrieving image with index 467
# retrieving image with index 468
# retrieving image with index 469
# retrieving image with index 470
# retrieving image with index 471
# retrieving image with index 472
# retrieving image with index 473
# retrieving image with index 474
# retrieving image with index 475
# retrieving image with index 476
# retrieving image with index 477
# retrieving image with index 478
# retrieving image with index 479
# retrieving image with index 480
# retrieving image with index 481
# retrieving image with index 482
# retrieving image with index 483
# retrieving image with index 484
# retrieving image with index 485
# retrieving image with index 486
# retrieving image with index 487
# retrieving image with index 488
# retrieving image with index 489
# retrieving image with index 490
# retrieving image with index 491
# retrieving image with index 492
# retrieving image with index 493
# retrieving image with index 494
# retrieving image with index 495
# retrieving image with index 496
# retrieving image with index 497
# retrieving image with index 498
# retrieving image with index 499
# retrieving image with index 500
# retrieving image with index 501
# retrieving image with index 502
# retrieving image with index 503
# retrieving image with index 504
# retrieving image with index 505
# retrieving image with index 506
# retrieving image with index 507
# retrieving image with index 508
# retrieving image with index 509
# retrieving image with index 510
# retrieving image with index 511
# retrieving image with index 512
# retrieving image with index 513
# retrieving image with index 514
# retrieving image with index 515
# retrieving image with index 516
# retrieving image with index 517
# retrieving image with index 518
# retrieving image with index 519
# retrieving image with index 520
# retrieving image with index 521
# retrieving image with index 522
# retrieving image with index 523
# retrieving image with index 524
# retrieving image with index 525
# retrieving image with index 526
# retrieving image with index 527
# retrieving image with index 528
# retrieving image with index 529
# retrieving image with index 530
# retrieving image with index 531
# retrieving image with index 532
# retrieving image with index 533
# retrieving image with index 534
# retrieving image with index 535
# retrieving image with index 536
# retrieving image with index 537
# retrieving image with index 538
# retrieving image with index 539
# retrieving image with index 540
# retrieving image with index 541
# retrieving image with index 542
# retrieving image with index 543
# retrieving image with index 544
# retrieving image with index 545
# retrieving image with index 546
# retrieving image with index 547
# retrieving image with index 548
# retrieving image with index 549
# retrieving image with index 550
# retrieving image with index 551
# retrieving image with index 552
# retrieving image with index 553
# retrieving image with index 554
# retrieving image with index 555
# retrieving image with index 556
# retrieving image with index 557
# retrieving image with index 558
# retrieving image with index 559
# retrieving image with index 560
# retrieving image with index 561
# retrieving image with index 562
# retrieving image with index 563
# retrieving image with index 564
# retrieving image with index 565
# retrieving image with index 566
# retrieving image with index 567
# retrieving image with index 568
# retrieving image with index 570
# retrieving image with index 571
# retrieving image with index 572
# retrieving image with index 573
# retrieving image with index 574
# retrieving image with index 575
# retrieving image with index 576
# retrieving image with index 577
# retrieving image with index 578
# retrieving image with index 579
# retrieving image with index 580
# retrieving image with index 581
# retrieving image with index 582
# retrieving image with index 583
# retrieving image with index 584
# retrieving image with index 585
# retrieving image with index 586
# retrieving image with index 587
# retrieving image with index 588
# retrieving image with index 589
# retrieving image with index 590
# retrieving image with index 591
# retrieving image with index 592
# retrieving image with index 593
# retrieving image with index 594
# retrieving image with index 595
# retrieving image with index 596
# retrieving image with index 597
# retrieving image with index 598
# retrieving image with index 599
# retrieving image with index 600
# retrieving image with index 601
# retrieving image with index 602
# retrieving image with index 603
# retrieving image with index 604
# retrieving image with index 605
# retrieving image with index 606
# retrieving image with index 607
# retrieving image with index 608
# retrieving image with index 609
# retrieving image with index 610
# retrieving image with index 611
# retrieving image with index 612
# retrieving image with index 613
# retrieving image with index 614
# retrieving image with index 615
# retrieving image with index 616
# retrieving image with index 617
# retrieving image with index 618
# retrieving image with index 619
# retrieving image with index 620
# retrieving image with index 621
# retrieving image with index 622
# retrieving image with index 623
# retrieving image with index 624
# retrieving image with index 625
# retrieving image with index 626
# retrieving image with index 627
# retrieving image with index 628
# retrieving image with index 629
# retrieving image with index 630
# retrieving image with index 631
# retrieving image with index 632
# retrieving image with index 633
# retrieving image with index 634
# retrieving image with index 635
# retrieving image with index 636
# retrieving image with index 637
# retrieving image with index 638
# retrieving image with index 639
# retrieving image with index 640
# retrieving image with index 641
# retrieving image with index 642
# retrieving image with index 643
# retrieving image with index 644
# retrieving image with index 645
# retrieving image with index 646
# retrieving image with index 647
# retrieving image with index 648
# retrieving image with index 649
# retrieving image with index 650
# retrieving image with index 651
# retrieving image with index 652
# retrieving image with index 653
# retrieving image with index 654
# retrieving image with index 655
# retrieving image with index 656
# retrieving image with index 657
# retrieving image with index 658
# retrieving image with index 659
# retrieving image with index 660
# retrieving image with index 661
# retrieving image with index 662
# retrieving image with index 663
# retrieving image with index 664
# retrieving image with index 665
# retrieving image with index 666
# retrieving image with index 667
# retrieving image with index 668
# retrieving image with index 669
# retrieving image with index 670
# retrieving image with index 671
# retrieving image with index 672
# retrieving image with index 673
# retrieving image with index 674
# retrieving image with index 675
# retrieving image with index 676
# retrieving image with index 677
# retrieving image with index 678
# retrieving image with index 679
# retrieving image with index 680
# retrieving image with index 681
# retrieving image with index 682
# retrieving image with index 683
# retrieving image with index 684
# retrieving image with index 685
# retrieving image with index 686
# retrieving image with index 687
# retrieving image with index 688
# retrieving image with index 689
# retrieving image with index 690
# retrieving image with index 691
# retrieving image with index 692
# retrieving image with index 693
# retrieving image with index 694
# retrieving image with index 695
# retrieving image with index 696
# retrieving image with index 697
# retrieving image with index 698
# retrieving image with index 699
# retrieving image with index 700
# retrieving image with index 701
# retrieving image with index 702
# retrieving image with index 703
# retrieving image with index 704
# retrieving image with index 705
# retrieving image with index 706
# retrieving image with index 707
# retrieving image with index 708
# retrieving image with index 709
# retrieving image with index 710
# retrieving image with index 711
# retrieving image with index 712
# retrieving image with index 713
# retrieving image with index 714
# retrieving image with index 715
# retrieving image with index 716
# retrieving image with index 717
# retrieving image with index 718
# retrieving image with index 719
# retrieving image with index 720
# retrieving image with index 721
# retrieving image with index 722
# retrieving image with index 723
# retrieving image with index 724
# retrieving image with index 725
# retrieving image with index 726
# retrieving image with index 727
# retrieving image with index 728
# retrieving image with index 729
# retrieving image with index 730
# retrieving image with index 731
# retrieving image with index 732
# retrieving image with index 733
# retrieving image with index 734
# retrieving image with index 735
# retrieving image with index 736
# retrieving image with index 737
# retrieving image with index 738
# retrieving image with index 739
# retrieving image with index 740
# retrieving image with index 741
# retrieving image with index 742
# retrieving image with index 743
# retrieving image with index 744
# retrieving image with index 745
# retrieving image with index 746
# retrieving image with index 747
# retrieving image with index 748
# retrieving image with index 749
# retrieving image with index 750
# retrieving image with index 751
# retrieving image with index 752
# retrieving image with index 753
# retrieving image with index 754
# retrieving image with index 755
# retrieving image with index 756
# retrieving image with index 757
# retrieving image with index 758
# retrieving image with index 759
# retrieving image with index 760
# retrieving image with index 761
# retrieving image with index 762
# retrieving image with index 763
# retrieving image with index 764
# retrieving image with index 765
# retrieving image with index 766
# retrieving image with index 767
# retrieving image with index 768
# retrieving image with index 769
# retrieving image with index 770
# retrieving image with index 771
# retrieving image with index 772
# retrieving image with index 773
# retrieving image with index 774
# retrieving image with index 775
# retrieving image with index 776
# retrieving image with index 777
# retrieving image with index 778
# retrieving image with index 779
# retrieving image with index 780
# retrieving image with index 781
# retrieving image with index 782
# retrieving image with index 783
# retrieving image with index 784
# retrieving image with index 785
# retrieving image with index 786
# retrieving image with index 787
# retrieving image with index 788
# retrieving image with index 789
# retrieving image with index 790
# retrieving image with index 791
# retrieving image with index 792
# retrieving image with index 793
# retrieving image with index 794
# retrieving image with index 795
# retrieving image with index 796
# retrieving image with index 797
# retrieving image with index 798
# retrieving image with index 799
# retrieving image with index 800
# retrieving image with index 801
# retrieving image with index 802
# retrieving image with index 803
# retrieving image with index 804
# retrieving image with index 805
# retrieving image with index 806
# retrieving image with index 807
# retrieving image with index 808
# retrieving image with index 809
# retrieving image with index 810
# retrieving image with index 811
# retrieving image with index 812
# retrieving image with index 813
# retrieving image with index 814
# retrieving image with index 815
# retrieving image with index 816
# retrieving image with index 817
# retrieving image with index 818
# retrieving image with index 819
# retrieving image with index 820
# retrieving image with index 821
# retrieving image with index 822
# retrieving image with index 823
# retrieving image with index 824
# retrieving image with index 825
# retrieving image with index 826
# retrieving image with index 827
# retrieving image with index 828
# retrieving image with index 829
# retrieving image with index 830
# retrieving image with index 831
# retrieving image with index 832
# retrieving image with index 833
# retrieving image with index 834
# retrieving image with index 835
# retrieving image with index 836
# retrieving image with index 837
# retrieving image with index 838
# retrieving image with index 839
# retrieving image with index 840
# retrieving image with index 841
# retrieving image with index 842
# retrieving image with index 843
# retrieving image with index 844
# retrieving image with index 845
# retrieving image with index 846
# retrieving image with index 847
# retrieving image with index 848
# retrieving image with index 849
# retrieving image with index 850
# retrieving image with index 851
# retrieving image with index 852
# retrieving image with index 853
# retrieving image with index 854
# retrieving image with index 855
# retrieving image with index 856
# retrieving image with index 857
# retrieving image with index 858
# retrieving image with index 859
# retrieving image with index 860
# retrieving image with index 861
# retrieving image with index 862
# retrieving image with index 863
# retrieving image with index 864
# retrieving image with index 865
# retrieving image with index 866
# retrieving image with index 867
# retrieving image with index 868
# retrieving image with index 869
# retrieving image with index 870
# retrieving image with index 871
# retrieving image with index 872
# retrieving image with index 873
# retrieving image with index 874
# retrieving image with index 875
# retrieving image with index 876
# retrieving image with index 877
# retrieving image with index 878
# retrieving image with index 879
# retrieving image with index 880
# retrieving image with index 881
# retrieving image with index 882
# retrieving image with index 883
# retrieving image with index 884
# retrieving image with index 885
# retrieving image with index 886
# retrieving image with index 887
# retrieving image with index 888
# retrieving image with index 889
# retrieving image with index 890
# retrieving image with index 891
# retrieving image with index 892
# retrieving image with index 893
# retrieving image with index 894
# retrieving image with index 895
# retrieving image with index 896
# retrieving image with index 897
# retrieving image with index 898
# retrieving image with index 899
# retrieving image with index 900
# retrieving image with index 901
# retrieving image with index 902
# retrieving image with index 903
# retrieving image with index 904
# retrieving image with index 905
# retrieving image with index 906
# retrieving image with index 907
# retrieving image with index 908
# retrieving image with index 909
# retrieving image with index 910
# retrieving image with index 911
# retrieving image with index 912
# retrieving image with index 913
# retrieving image with index 914
# retrieving image with index 915
# retrieving image with index 916
# retrieving image with index 917
# retrieving image with index 918
# retrieving image with index 919
# retrieving image with index 920
# retrieving image with index 921
# retrieving image with index 922
# retrieving image with index 923
# retrieving image with index 924
# retrieving image with index 925
# retrieving image with index 926
# retrieving image with index 927
# retrieving image with index 928
# retrieving image with index 929
# retrieving image with index 930
# retrieving image with index 931
# retrieving image with index 932
# retrieving image with index 933
# retrieving image with index 934
# retrieving image with index 935
# retrieving image with index 936
# retrieving image with index 937
# retrieving image with index 938
# retrieving image with index 939
# retrieving image with index 940
# retrieving image with index 941
# retrieving image with index 942
# retrieving image with index 943
# retrieving image with index 944
# retrieving image with index 945
# retrieving image with index 946
# retrieving image with index 947
# retrieving image with index 948
# retrieving image with index 949
# retrieving image with index 950
# retrieving image with index 951
# retrieving image with index 952
# retrieving image with index 953
# retrieving image with index 954
# retrieving image with index 955
# retrieving image with index 956
# retrieving image with index 957
# retrieving image with index 958
# retrieving image with index 959
# retrieving image with index 960
# retrieving image with index 961
# retrieving image with index 962
# retrieving image with index 963
# retrieving image with index 964
# retrieving image with index 965
# retrieving image with index 966
# retrieving image with index 967
# retrieving image with index 968
# retrieving image with index 969
# retrieving image with index 970
# retrieving image with index 971
# retrieving image with index 972
# retrieving image with index 973
# retrieving image with index 974
# retrieving image with index 975
# retrieving image with index 976
# retrieving image with index 977
# retrieving image with index 978
# retrieving image with index 979
# retrieving image with index 980
# retrieving image with index 981
# retrieving image with index 982
# retrieving image with index 983
# retrieving image with index 984
# retrieving image with index 985
# retrieving image with index 986
# retrieving image with index 987
# retrieving image with index 988
# retrieving image with index 989
# retrieving image with index 990
# retrieving image with index 991
# retrieving image with index 992
# retrieving image with index 993
# retrieving image with index 994
# retrieving image with index 995
# retrieving image with index 996
# retrieving image with index 997
# retrieving image with index 998
# retrieving image with index 999

# %%
def get_star_image_2(params):
    image_name = url.split('/')[-1]
    if not os.path.isfile(f'../data/images/{image_name}'):
        resp = req.get(url)
        resp = req.get('https://skyserver.sdss.org/dr18/SkyServerWS/ImgCutout/getjpeg', params)
        f = open(f'../data/images/{image_name}','wb')
        f.write(resp.content)
        f.close()
